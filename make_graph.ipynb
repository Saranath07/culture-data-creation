# %%
from graphviz import Digraph

# Create a Digraph object
dot = Digraph(comment='Indian Culture', format='png')

# Root node
dot.node('A', 'Indian Culture', color='black', style='filled', fillcolor='lightgray')

# Religion
dot.node('B', 'Religion', color='blue', style='filled', fillcolor='lightblue')
dot.edge('A', 'B')
dot.node('B1', 'Hinduism', color='blue', style='filled', fillcolor='skyblue')
dot.node('B2', 'Islam', color='blue', style='filled', fillcolor='skyblue')
dot.node('B3', 'Christianity', color='blue', style='filled', fillcolor='skyblue')
dot.node('B4', 'Sikhism', color='blue', style='filled', fillcolor='skyblue')
dot.node('B5', 'Buddhism', color='blue', style='filled', fillcolor='skyblue')
dot.node('B6', 'Jainism', color='blue', style='filled', fillcolor='skyblue')
dot.node('B7', 'Other (Zoroastrianism, Judaism, etc.)', color='blue', style='filled', fillcolor='skyblue')
dot.edge('B', 'B1')
dot.edge('B', 'B2')
dot.edge('B', 'B3')
dot.edge('B', 'B4')
dot.edge('B', 'B5')
dot.edge('B', 'B6')
dot.edge('B', 'B7')

# Languages
dot.node('C', 'Languages', color='green', style='filled', fillcolor='lightgreen')
dot.edge('A', 'C')
dot.node('C1', 'Indo-Aryan Languages', color='green', style='filled', fillcolor='palegreen')
dot.node('C2', 'Dravidian Languages', color='green', style='filled', fillcolor='palegreen')
dot.node('C3', 'Other Language Families', color='green', style='filled', fillcolor='palegreen')
dot.edge('C', 'C1')
dot.edge('C', 'C2')
dot.edge('C', 'C3')
dot.node('C1_1', 'Hindi', color='green', style='filled', fillcolor='palegreen')
dot.node('C1_2', 'Bengali', color='green', style='filled', fillcolor='palegreen')
dot.node('C1_3', 'Marathi', color='green', style='filled', fillcolor='palegreen')
dot.node('C1_4', 'Gujarati', color='green', style='filled', fillcolor='palegreen')
dot.node('C1_5', 'Punjabi', color='green', style='filled', fillcolor='palegreen')
dot.edge('C1', 'C1_1')
dot.edge('C1', 'C1_2')
dot.edge('C1', 'C1_3')
dot.edge('C1', 'C1_4')
dot.edge('C1', 'C1_5')
dot.node('C2_1', 'Tamil', color='green', style='filled', fillcolor='palegreen')
dot.node('C2_2', 'Telugu', color='green', style='filled', fillcolor='palegreen')
dot.node('C2_3', 'Kannada', color='green', style='filled', fillcolor='palegreen')
dot.node('C2_4', 'Malayalam', color='green', style='filled', fillcolor='palegreen')
dot.edge('C2', 'C2_1')
dot.edge('C2', 'C2_2')
dot.edge('C2', 'C2_3')
dot.edge('C2', 'C2_4')
dot.node('C3_1', 'Tibeto-Burman', color='green', style='filled', fillcolor='palegreen')
dot.node('C3_2', 'Austroasiatic', color='green', style='filled', fillcolor='palegreen')
dot.edge('C3', 'C3_1')
dot.edge('C3', 'C3_2')

# Festivals
dot.node('D', 'Festivals', color='red', style='filled', fillcolor='lightcoral')
dot.edge('A', 'D')
dot.node('D1', 'National Festivals', color='red', style='filled', fillcolor='salmon')
dot.node('D2', 'Regional Festivals', color='red', style='filled', fillcolor='salmon')
dot.edge('D', 'D1')
dot.edge('D', 'D2')
dot.node('D1_1', 'Diwali', color='red', style='filled', fillcolor='salmon')
dot.node('D1_2', 'Holi', color='red', style='filled', fillcolor='salmon')
dot.node('D1_3', 'Eid', color='red', style='filled', fillcolor='salmon')
dot.node('D1_4', 'Christmas', color='red', style='filled', fillcolor='salmon')
dot.node('D1_5', 'Vaisakhi', color='red', style='filled', fillcolor='salmon')
dot.edge('D1', 'D1_1')
dot.edge('D1', 'D1_2')
dot.edge('D1', 'D1_3')
dot.edge('D1', 'D1_4')
dot.edge('D1', 'D1_5')
dot.node('D2_1', 'Pongal (Tamil Nadu)', color='red', style='filled', fillcolor='salmon')
dot.node('D2_2', 'Bihu (Assam)', color='red', style='filled', fillcolor='salmon')
dot.node('D2_3', 'Durga Puja (West Bengal)', color='red', style='filled', fillcolor='salmon')
dot.node('D2_4', 'Ganesh Chaturthi (Maharashtra)', color='red', style='filled', fillcolor='salmon')
dot.edge('D2', 'D2_1')
dot.edge('D2', 'D2_2')
dot.edge('D2', 'D2_3')
dot.edge('D2', 'D2_4')

# Food and Cuisine
dot.node('E', 'Food and Cuisine', color='orange', style='filled', fillcolor='wheat')
dot.edge('A', 'E')
dot.node('E1', 'North Indian Cuisine', color='orange', style='filled', fillcolor='moccasin')
dot.node('E2', 'South Indian Cuisine', color='orange', style='filled', fillcolor='moccasin')
dot.node('E3', 'East Indian Cuisine', color='orange', style='filled', fillcolor='moccasin')
dot.node('E4', 'West Indian Cuisine', color='orange', style='filled', fillcolor='moccasin')
dot.edge('E', 'E1')
dot.edge('E', 'E2')
dot.edge('E', 'E3')
dot.edge('E', 'E4')
dot.node('E1_1', 'Punjabi (Butter Chicken, Naan)', color='orange', style='filled', fillcolor='lightyellow')
dot.node('E1_2', 'Mughlai (Biryani, Kebabs)', color='orange', style='filled', fillcolor='lightyellow')
dot.node('E2_1', 'Tamil Nadu (Dosa, Sambar)', color='orange', style='filled', fillcolor='lightyellow')
dot.node('E2_2', 'Kerala (Appam, Avial)', color='orange', style='filled', fillcolor='lightyellow')
dot.node('E3_1', 'Bengali (Fish Curry, Mishti Doi)', color='orange', style='filled', fillcolor='lightyellow')
dot.node('E4_1', 'Gujarati (Dhokla, Thepla)', color='orange', style='filled', fillcolor='lightyellow')
dot.edge('E1', 'E1_1')
dot.edge('E1', 'E1_2')
dot.edge('E2', 'E2_1')
dot.edge('E2', 'E2_2')
dot.edge('E3', 'E3_1')
dot.edge('E4', 'E4_1')

# Arts and Crafts
dot.node('F', 'Arts and Crafts', color='purple', style='filled', fillcolor='lavender')
dot.edge('A', 'F')
dot.node('F1', 'Classical Music', color='purple', style='filled', fillcolor='plum')
dot.node('F2', 'Classical Dance Forms', color='purple', style='filled', fillcolor='plum')
dot.node('F3', 'Handicrafts', color='purple', style='filled', fillcolor='plum')
dot.edge('F', 'F1')
dot.edge('F', 'F2')
dot.edge('F', 'F3')
dot.node('F1_1', 'Hindustani', color='purple', style='filled', fillcolor='orchid')
dot.node('F1_2', 'Carnatic', color='purple', style='filled', fillcolor='orchid')
dot.node('F2_1', 'Bharatanatyam', color='purple', style='filled', fillcolor='orchid')

dot.node('F2_2', 'Kathak', color='purple', style='filled', fillcolor='orchid')
dot.node('F2_3', 'Kathakali', color='purple', style='filled', fillcolor='orchid')
dot.node('F2_4', 'Odissi', color='purple', style='filled', fillcolor='orchid')
dot.node('F3_1', 'Madhubani Paintings', color='purple', style='filled', fillcolor='orchid')
dot.node('F3_2', 'Pattachitra', color='purple', style='filled', fillcolor='orchid')
dot.node('F3_3', 'Handloom Weaving', color='purple', style='filled', fillcolor='orchid')
dot.edge('F1', 'F1_1')
dot.edge('F1', 'F1_2')
dot.edge('F2', 'F2_1')
dot.edge('F2', 'F2_2')
dot.edge('F2', 'F2_3')
dot.edge('F2', 'F2_4')
dot.edge('F3', 'F3_1')
dot.edge('F3', 'F3_2')
dot.edge('F3', 'F3_3')

# Architecture and Monuments
dot.node('G', 'Architecture and Monuments', color='teal', style='filled', fillcolor='lightcyan')
dot.edge('A', 'G')
dot.node('G1', 'Temples', color='teal', style='filled', fillcolor='paleturquoise')
dot.node('G2', 'Mosques', color='teal', style='filled', fillcolor='paleturquoise')
dot.node('G3', 'Historical Monuments', color='teal', style='filled', fillcolor='paleturquoise')
dot.node('G4', 'Forts and Palaces', color='teal', style='filled', fillcolor='paleturquoise')
dot.edge('G', 'G1')
dot.edge('G', 'G2')
dot.edge('G', 'G3')
dot.edge('G', 'G4')
dot.node('G1_1', 'Brihadeeswarar Temple (Tamil Nadu)', color='teal', style='filled', fillcolor='paleturquoise')
dot.node('G2_1', 'Jama Masjid (Delhi)', color='teal', style='filled', fillcolor='paleturquoise')
dot.node('G3_1', 'Taj Mahal', color='teal', style='filled', fillcolor='paleturquoise')
dot.node('G3_2', 'Red Fort', color='teal', style='filled', fillcolor='paleturquoise')
dot.node('G4_1', 'Mehrangarh Fort', color='teal', style='filled', fillcolor='paleturquoise')
dot.node('G4_2', 'City Palace, Jaipur', color='teal', style='filled', fillcolor='paleturquoise')
dot.edge('G1', 'G1_1')
dot.edge('G2', 'G2_1')
dot.edge('G3', 'G3_1')
dot.edge('G3', 'G3_2')
dot.edge('G4', 'G4_1')
dot.edge('G4', 'G4_2')

# Regional Variations
dot.node('H', 'Regional Variations', color='brown', style='filled', fillcolor='peachpuff')
dot.edge('A', 'H')
dot.node('H1', 'North India', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H2', 'South India', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H3', 'East India', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H4', 'West India', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.edge('H', 'H1')
dot.edge('H', 'H2')
dot.edge('H', 'H3')
dot.edge('H', 'H4')
dot.node('H1_1', 'Uttar Pradesh', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H1_2', 'Delhi', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H2_1', 'Tamil Nadu', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H2_2', 'Karnataka', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H3_1', 'West Bengal', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H3_2', 'Odisha', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H4_1', 'Maharashtra', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.node('H4_2', 'Gujarat', color='brown', style='filled', fillcolor='lightgoldenrod')
dot.edge('H1', 'H1_1')
dot.edge('H1', 'H1_2')
dot.edge('H2', 'H2_1')
dot.edge('H2', 'H2_2')
dot.edge('H3', 'H3_1')
dot.edge('H3', 'H3_2')
dot.edge('H4', 'H4_1')
dot.edge('H4', 'H4_2')

# Traditions and Rituals
dot.node('I', 'Traditions and Rituals', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.edge('A', 'I')
dot.node('I1', 'Weddings', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.node('I2', 'Birth Ceremonies', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.node('I3', 'Funeral Rites', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.edge('I', 'I1')
dot.edge('I', 'I2')
dot.edge('I', 'I3')
dot.node('I1_1', 'Hindu', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.node('I1_2', 'Muslim', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.node('I1_3', 'Christian', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.node('I2_1', 'Annaprashan', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.node('I2_2', 'Namkaran', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.node('I3_1', 'Antyeshti', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.node('I3_2', 'Burial', color='darkgreen', style='filled', fillcolor='lightgreen')
dot.edge('I1', 'I1_1')
dot.edge('I1', 'I1_2')
dot.edge('I1', 'I1_3')
dot.edge('I2', 'I2_1')
dot.edge('I2', 'I2_2')
dot.edge('I3', 'I3_1')
dot.edge('I3', 'I3_2')

# Render the graph to a file (e.g., PNG)
dot.render('indian_culture_hierarchy', view=True)
# Out:
# 'indian_culture_hierarchy.png'
